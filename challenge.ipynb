# %% [markdown]
# # CV Challenge: ResNet50 on Flowers dataset

# %%
# install required packages
# %pip install matplotlib
# Out:
# Requirement already satisfied: validators in c:\users\aadhi\miniconda3\envs\notebook\lib\site-packages (0.28.1)
# Requirement already satisfied: matplotlib in c:\users\aadhi\miniconda3\envs\notebook\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aadhi\miniconda3\envs\notebook\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\aadhi\miniconda3\envs\notebook\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aadhi\miniconda3\envs\notebook\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aadhi\miniconda3\envs\notebook\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\aadhi\miniconda3\envs\notebook\lib\site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\aadhi\miniconda3\envs\notebook\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\aadhi\miniconda3\envs\notebook\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aadhi\miniconda3\envs\notebook\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aadhi\miniconda3\envs\notebook\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\aadhi\miniconda3\envs\notebook\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# imports
import os
import torch
import torch.nn as nn
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import warnings
from collections import Counter
from PIL import Image
from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler
from torch.optim.lr_scheduler import ExponentialLR
from torchvision import transforms
from torchvision.models import resnet50
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# setup device for inference
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(f'Using {device} for inference')
# Out:
# Using cpu for inference

# %%
# get the pretrained reset50 model
resnet50_model = resnet50(pretrained=True)

# %%
# custom dataset class for the flowers dataset
class FlowersDataset(Dataset):
    def __init__(self, image_folder, labels_file, indices, transform=None):
        self.image_folder = image_folder
        self.transform = transform

        self.labels = scipy.io.loadmat(labels_file)['labels'].squeeze()
        self.image_files = os.listdir(image_folder)
        self.indices = indices
    
    def __len__(self):
        return len(self.indices)

    def __getitem__(self, index):
        real_idx = self.indices[index]
        img_name = os.path.join(self.image_folder, self.image_files[real_idx])
        image = Image.open(img_name).convert('RGB')

        if self.transform:
            image = self.transform(image)
        
        return image, self.labels[real_idx]

# %%
# check the class distribution of the data
labels_file = "./imagelabels.mat"
labels_data = scipy.io.loadmat(labels_file)
labels = labels_data['labels'].squeeze()

class_counts = Counter(labels)

# Print the counts
print("Class distribution:")
for label, count in class_counts.items():
    print(f"Class {label}: {count} samples")

# Plot the class distribution
plt.bar(class_counts.keys(), class_counts.values())
plt.xlabel('Class')
plt.ylabel('Number of samples')
plt.title('Class distribution')
plt.show()
# Out:
# Class distribution:
# Class 77: 251 samples
# Class 73: 194 samples
# Class 88: 154 samples
# Class 89: 184 samples
# Class 81: 166 samples
# Class 46: 196 samples
# Class 74: 171 samples
# Class 51: 258 samples
# Class 44: 93 samples
# Class 82: 112 samples
# Class 83: 131 samples
# Class 78: 137 samples
# Class 80: 105 samples
# Class 75: 120 samples
# Class 41: 127 samples
# Class 43: 130 samples
# Class 76: 107 samples
# Class 84: 86 samples
# Class 58: 114 samples
# Class 56: 109 samples
# Class 86: 58 samples
# Class 60: 109 samples
# Class 92: 66 samples
# Class 11: 87 samples
# Class 65: 102 samples
# Class 8: 85 samples
# Class 23: 91 samples
# Class 30: 85 samples
# Class 72: 96 samples
# Class 53: 93 samples
# Class 37: 108 samples
# Class 17: 85 samples
# Class 12: 87 samples
# Class 29: 78 samples
# Class 52: 85 samples
# Class 18: 82 samples
# Class 36: 75 samples
# Class 90: 82 samples
# Class 71: 78 samples
# Class 40: 67 samples
# Class 48: 71 samples
# Class 55: 71 samples
# Class 85: 63 samples
# Class 91: 76 samples
# Class 20: 56 samples
# Class 47: 67 samples
# Class 59: 67 samples
# Class 2: 60 samples
# Class 5: 65 samples
# Class 28: 66 samples
# Class 70: 62 samples
# Class 22: 59 samples
# Class 54: 61 samples
# Class 87: 63 samples
# Class 66: 61 samples
# Class 32: 45 samples
# Class 4: 56 samples
# Class 42: 59 samples
# Class 13: 49 samples
# Class 38: 56 samples
# Class 63: 54 samples
# Class 68: 54 samples
# Class 69: 54 samples
# Class 93: 46 samples
# Class 14: 48 samples
# Class 64: 52 samples
# Class 19: 49 samples
# Class 49: 49 samples
# Class 61: 50 samples
# Class 50: 92 samples
# Class 15: 49 samples
# Class 9: 46 samples
# Class 33: 46 samples
# Class 26: 41 samples
# Class 25: 41 samples
# Class 3: 40 samples
# Class 16: 41 samples
# Class 79: 41 samples
# Class 1: 40 samples
# Class 21: 40 samples
# Class 24: 42 samples
# Class 27: 40 samples
# Class 31: 52 samples
# Class 34: 40 samples
# Class 35: 43 samples
# Class 39: 41 samples
# Class 67: 42 samples
# Class 10: 45 samples
# Class 45: 40 samples
# Class 6: 45 samples
# Class 7: 40 samples
# Class 57: 67 samples
# Class 62: 55 samples
# Class 94: 162 samples
# Class 95: 128 samples
# Class 96: 91 samples
# Class 97: 66 samples
# Class 98: 82 samples
# Class 99: 63 samples
# Class 100: 49 samples
# Class 101: 58 samples
# Class 102: 48 samples

# %%
# get the data split indices
data_split = scipy.io.loadmat('setid.mat')

# get the indices for training, testing, and validtaion data
train_idx = data_split['trnid'].squeeze()
test_idx = data_split['tstid'].squeeze()
val_idx = data_split['valid'].squeeze()

# %%
# hyperparamters
LEARNING_RATE = 0.1
NUM_EPOCHS = 15
GAMMA = 0.9

# %%
# training data transform - includes transforms to minimize overfitting
data_transform_train = transforms.Compose([
  transforms.RandomResizedCrop(224),
  transforms.RandomHorizontalFlip(),
  transforms.ColorJitter(),
  transforms.RandomRotation(10),
  transforms.ToTensor(),
  transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# validation data transforms
data_transform_val = transforms.Compose([
  transforms.Resize(256),
  transforms.CenterCrop(224),
  transforms.ToTensor(),
  transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
images_dir = "./Flowers/jpg"

# store the training and validation datasets into memory (based on indices obtained from a previous step)
train_dataset = FlowersDataset(images_dir, labels_file, train_idx, transform=data_transform_train)
val_dataset = FlowersDataset(images_dir, labels_file, val_idx, transform=data_transform_val)

# method that provides weights for each of the labels in the dataset
def get_class_weights(labels):
    class_sample_count = np.array([len(np.where(labels == t)[0]) for t in np.unique(labels)])
    weight = 1. / class_sample_count
    samples_weight = np.array([weight[t - 1] for t in labels])
    return samples_weight

# class weighting to accomodate for the uneven class distribution
train_labels = np.array([label for _, label in train_dataset])
samples_weight = get_class_weights(train_labels)
samples_weight = torch.from_numpy(samples_weight).double()
sampler = WeightedRandomSampler(samples_weight, len(samples_weight))

# create data loaders from the training and validation dataset
train_data_loader = DataLoader(train_dataset, batch_size=32, sampler=sampler)
val_data_loader = DataLoader(val_dataset, batch_size=32, shuffle=True)


num_classes = len(class_counts)
num_features = resnet50_model.fc.in_features

# set the output layer of the model based on the class labels we have
resnet50_model.fc = nn.Sequential(
  nn.Dropout(0.5),
  nn.Linear(num_features, num_classes)
) 

# loss function
loss_fuction = torch.nn.CrossEntropyLoss()

# optimizer
optimizer = torch.optim.SGD(resnet50_model.parameters(), lr=LEARNING_RATE)

# lr scheduler
scheduler = ExponentialLR(optimizer, gamma=GAMMA)
resnet50_model = resnet50_model.to(device)

# %%
best_val_loss = float('inf')

# training process
for epoch in range(NUM_EPOCHS):
    print(f"Epoch {epoch+1}/{NUM_EPOCHS}")
    print("-" * 10)

    # set model to training phase
    resnet50_model.train()

    running_loss = 0.0
    running_corrects = 0

    # iterate over the data from the training data loader
    for inputs, labels in train_data_loader:
        inputs, labels = inputs.to(device), (labels - 1).to(device)

        optimizer.zero_grad()

        outputs = resnet50_model(inputs)

        _, preds = torch.max(outputs, 1)
        loss = loss_fuction(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    # step the exponential LR scheduler
    scheduler.step()

    # calculate statistics
    epoch_loss = running_loss / len(train_data_loader.dataset)
    epoch_acc = 100. * running_corrects.double() / len(train_data_loader.dataset)

    print(f'Training    ==> Loss: {epoch_loss:.4f} | Acc: {epoch_acc:.2f}%')

    # Validation loop
    # set the model to validation phase
    resnet50_model.eval()
    val_loss = 0.0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        # iterate over the data from the validation data loader
        for inputs, labels in val_data_loader:
            inputs, labels = inputs.to(device), (labels - 1).to(device)
            outputs = resnet50_model(inputs)

            loss = loss_fuction(outputs, labels)
            val_loss += loss.item()
            _, preds = outputs.max(1)
            val_total += labels.size(0)
            val_correct += preds.eq(labels).sum().item()

    # calculate the statistics
    val_loss /= len(val_data_loader)
    val_acc = 100. * val_correct / val_total

    print(f'Validation  ==> Loss: {val_loss:.4f} | Acc: {val_acc:.2f}%\n')

    # save the best model to the best_model.pth file
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        # save the model with the best loss value
        torch.save(resnet50_model.state_dict(), 'best_model.pth')
# Out:
# Epoch 1/15
# ----------
# Training    ==> Loss: 4.1898 | Acc: 12.06%
# Validation  ==> Loss: 3.4795 | Acc: 23.82%
#
# Epoch 2/15
# ----------
# Training    ==> Loss: 2.5005 | Acc: 37.94%
# Validation  ==> Loss: 1.8759 | Acc: 50.98%
#
# Epoch 3/15
# ----------
# Training    ==> Loss: 1.4643 | Acc: 61.76%
# Validation  ==> Loss: 1.8755 | Acc: 54.80%
#
# Epoch 4/15
# ----------
# Training    ==> Loss: 0.9371 | Acc: 76.37%
# Validation  ==> Loss: 0.9666 | Acc: 76.37%
#
# Epoch 5/15
# ----------
# Training    ==> Loss: 0.6613 | Acc: 83.14%
# Validation  ==> Loss: 0.7576 | Acc: 79.22%
#
# Epoch 6/15
# ----------
# Training    ==> Loss: 0.5501 | Acc: 86.57%
# Validation  ==> Loss: 0.6237 | Acc: 85.29%
#
# Epoch 7/15
# ----------
# Training    ==> Loss: 0.3893 | Acc: 91.18%
# Validation  ==> Loss: 0.5357 | Acc: 87.65%
#
# Epoch 8/15
# ----------
# Training    ==> Loss: 0.3168 | Acc: 92.45%
# Validation  ==> Loss: 0.5997 | Acc: 84.61%
#
# Epoch 9/15
# ----------
# Training    ==> Loss: 0.2881 | Acc: 93.92%
# Validation  ==> Loss: 0.5715 | Acc: 86.08%
#
# Epoch 10/15
# ----------
# Training    ==> Loss: 0.2368 | Acc: 95.20%
# Validation  ==> Loss: 0.4096 | Acc: 90.49%
#
# Epoch 11/15
# ----------
# Training    ==> Loss: 0.2448 | Acc: 94.41%
# Validation  ==> Loss: 0.4655 | Acc: 88.92%
#
# Epoch 12/15
# ----------
# Training    ==> Loss: 0.2049 | Acc: 96.57%
# Validation  ==> Loss: 0.4325 | Acc: 90.10%
#
# Epoch 13/15
# ----------
# Training    ==> Loss: 0.1841 | Acc: 95.29%
# Validation  ==> Loss: 0.4430 | Acc: 87.94%
#
# Epoch 14/15
# ----------
# Training    ==> Loss: 0.1678 | Acc: 96.37%
# Validation  ==> Loss: 0.4256 | Acc: 89.90%
#
# Epoch 15/15
# ----------
# Training    ==> Loss: 0.2260 | Acc: 94.51%
# Validation  ==> Loss: 0.4067 | Acc: 89.51%
